// %%
println!("{a:04}");
// Out:
// [E0425] Error: cannot find value `a` in this scope
//    ╭─[command_2:1:1]
//    │
//  3 │ println!("{a:04}");
//    │            ┬
//    │            ╰── not found in this scope
// ───╯
